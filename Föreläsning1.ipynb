# %% [markdown]
# $$ \require{cancel} $$

# %% [markdown]
# # Introduktion
#
# Hugo Strand (2020)
#
# - Förkunskaper: Flervariabelanalys och klassisk mekanik.
# - Textbok: F. Mandl, *Statistical Physics*, 2nd Ed.
#
# Översikt
# - Mikro- och makro-tillstånd
# - Termodynamikens första och andra huvudsatser
# - Temperaturhärledning
# - Fundamentala termodynamiska relationen
# - Termodynamiska potentialer
#
# ***

# %% [markdown]
# # Mikroskopisk och Makroskopisk Fysik
#
# Ex: Gas i en behållare
#
# <img src="./figurer/figur1.svg">
#
# __Mikrotillstånd__:
# - $N$ atomer
# - Positioner $\vec{r}_1, \vec{r}_2, \dots, \vec{v}_N$
# - Hastigheter $\vec{v}_1, \vec{v}_2, \dots, \vec{v}_N$
#
# **Makrotillstånd**:
# - $N$ atomer
# - Intern energi $E$ (totala energin i interna frihetsgrader, t.ex. $E_{kin}$)
# - Volym $V$
#
# ***

# %% [markdown]
# # Energikonservering
#
# Process: $E_1 \rightarrow E_2$
#
# Isolerat system: $$E_2 - E_1 = \Delta E = W$$
# där $W$ är arbetet utfört *på* systemet.
#
# Ej isolerat system: $\Delta E \ne W$
# $$\Delta E - W = Q$$
# där $Q$ är mängden tillförd värme
#
# $\quad \Rightarrow \quad
# \Delta E = Q + W
# \quad \Leftrightarrow \quad
# dE = dQ + dW$
#
# Arbete $W$ och värme $Q$ är två typer av *energiöverföring*.
#
# För processen: $E_1 \rightarrow E_2$
#
# $$ \Delta E = E_2 - E_1 \quad\quad \text{väldefinierad} $$
# $$ \Delta E = Q + W \quad\quad \text{väldefinierad} $$
#
# Men $Q$ och $W$ är *ej* väldefinierade, då de beror på *hur* processe gjordes.
#
# $E$ beror bara på start- och slut-punkt
#
# $\Rightarrow \quad E$ är en **tillståndsfunktion**.
#
# ## Termodynamikens första huvudsats
#
# $$ dE = \cancel{d}Q \, + \cancel{d} W \quad\quad \text{(TD1)} $$
#
# ***

# %% [markdown]
# # Tankeexperiment
#
# Isolerat system med en gas
#
# ### 1. Jämvikt (med vägg)
#
# Intern energy $E_1$, volym $V_1$ och antal atomer $N_1$
#
# <img src="./figurer/figur2_1.svg">
#
# ### 2. Ta bort väggen (icke jämvikt)
#
# <img src="./figurer/figur2_2.svg">
#
# ### 3. Ny jämvikt
#
# <img src="./figurer/figur2_3.svg">
#
# $$ N_3 = N_1 , V_3 = 2 V_1 $$
#
# $$ \text{(TD1) :} \quad dE = \cancel{d}Q + \cancel{d}W = 0 \quad \Rightarrow E_3 = E_1$$
#
# ## Fråga:
#
# Varför observerar vi aldrig processen $3 \rightarrow 2$?
#
# ***

# %% [markdown]
# ## Svar:
#
# Sannorlikheten för $N \approx 10^{23}$ atomer att spontant geonomgå $3 \rightarrow 2$ är *försummbar*.
#
# Eftersom:
#
# - Antal homogena *mikrotillstånd* $\gg$ antal *mikrotillstånd* med alla partiklar till vänster.
#
# Fluktuationer: $\sim \frac{1}{\sqrt{N}} \sim 10^{-10} \ll 1$ (se textboken)
#
# ***

# %% [markdown]
# # Kvantifiering
#
# ### Definition: Statistiska vikten av ett *makrotillstånd* $\Omega$
#
# Jämvikt:
#
# $$ \Omega = \Omega(E,V,N) = \left( \begin{array}{c} \text{Andel mikrotillstånd motsv.}\\ \text{makrotillståndet (E,V,N)} \end{array} \right) $$
#
# Icke jämvikt:
#
# $$ \Omega = \Omega(E,V,N, \alpha) $$
#
# där $\alpha$ är övriga makroskopiska icke jämvikts parametrar, se exempel nedan.
#
# ### Postulat
#
# **(i)** Alla mikrotillstång kompatibla med ett makrotillstånd $(E,V,N,\alpha)$ är lika sannorlika.
#
# **(ii)** Termodynamisk jämvikt svarar mot $\alpha$ som maximerar $\Omega(E,V,N,\alpha)$.
#
# ### Deifiniton: Entropi $S \equiv k \ln \Omega$
#
# Mått på oordning i ett givet makrotillstånd $\approx$ antal mikrotillstånd som systemet fluktuerar mellan.
#
# ($S$ lättare att använda i praktiken än $\Omega$)
#
# Postulat **(i)** och **(ii)** $\Rightarrow$
# - För ett isolerat system ökar entropin $S$ och i jämvikt har $S$ sitt maximala värde.
#
# # Termodynamikens andra huvudsats
#
# För ett isolerat system
# $$ dS \ge 0 \quad \quad \text{(TD2)} $$
#
# ***

# %% [markdown]
# # Härledning av temperatur
#
# Isolerat system med en gas och konstant $E$, $V$, $N$
#
# Dela upp i två delar (1) och (2)
#
# $$ E = E_1 + E_2 \\ V = V_1 + V_2 \\ N = N_1 + N_2 $$
#
# <img src="./figurer/figur3.svg">
#
# För hela systemet
#
# $$ \Omega = \Omega_1 \cdot \Omega_2 $$
#
# Totala entropin
#
# $$ S = k \ln \Omega = k \ln \left( \Omega_1 \cdot \Omega_2 \right) = k \ln \Omega_1 + k \ln \Omega_2 = S_1 + S_2$$
#
# Icke jämvikt:
# $$S = S(E,V,N,\alpha) \, , \quad \text{låt } \alpha = \{ E_1, V_1, N_1 \}$$
#
# $$ \Rightarrow \quad\quad
# S = S(E,V,N,E_1,V_1,N_1) = S_1(E_1, V_1, N_1) + S_2(E_2, V_2, N_2) $$
#
# **Låt:** Separationen vara en värmeledande vägg
#
# $\Rightarrow \quad dV_1 = dN_1 = 0$, isolerad $\cancel{d}W=0$, (TD1) $dE_1 = \cancel{d}Q + \cancel{d}W = \cancel{d}Q$
#
# D.v.s. värme kan flöda mellan (1) och (2).
#
# #### Förväntan: Vid jämvikt har (1) och (2) samma temperatur $T_1 = T_2$
#
# Antag jämvikt: (TD2) $\Rightarrow dS = 0$
#
# $$
# 0
# =
# \left( \frac{\partial S}{\partial E_1} \right)_{E,V,N;V_1,N_1}
# =
# \left( \frac{\partial S_1}{\partial E_1} \right)_{V_1,N_1}
# +
# \left( \frac{\partial S_2}{\partial E_2} \right)_{V_2,N_2}
# \frac{dE_1}{dE_1}
# $$
#
# eftersom $E_2 = E - E_1$, $\frac{dE_2}{dE_1} = -1$ får vi jämviktsvillkoret
#
# $$ \left( \frac{\partial S_1}{\partial E_1} \right)_{V_1,N_1}
# =
# \left( \frac{\partial S_2}{\partial E_2} \right)_{V_2,N_2} $$
#
# vilket måste vara relaterat till temperaturerna hos (1) och (2)
#
# #### Definition: Temperatur $$T \equiv \left( \frac{\partial E}{\partial S} \right)_{V,N}$$
#
# Vilket innebär
# $$ \Rightarrow \quad \left( \frac{\partial S_1}{\partial E_1} \right)_{V_1,N_1}
# =
# \left( \frac{\partial S_2}{\partial E_2} \right)_{V_2,N_2}
# \quad \Leftrightarrow \quad
# \frac{1}{T_1} = \frac{1}{T_2}
# \quad \Leftrightarrow \quad
# T_1 = T_2
# $$
#
# I jämvikt har båda delarna (1) och (2) samma temperatur.
#
# ## Koll:
#
# Icke jämvikt och (TD2): $dS > 0$
#
# $$ \Rightarrow \quad
# \frac{dS}{dt} =
# \left(\frac{1}{T_1} - \frac{1}{T_2}\right) \frac{dE_1}{dt} > 0 $$
#
# Om $T_1 < T_2$ så är $dE_1 > 0$, d.v.s. värme flödar från den varma delen (2) till den kalla (1).
#
# $\Rightarrow$ Temperatur definitionen $T \equiv \left( \frac{\partial E}{\partial S} \right)_{V,N}$ stämmer med våra förväntningar.
#
# ## Utmaning
#
# Härled ytterligare två jämvikts villkor genom att behandla fallet med rörlig vägg ($dV_1 \ne 0$) och genomträngligt membran ($dN_1 \ne 0$).
#
# ***

# %% [markdown]
# # Konjungerade variabler
#
# Temperaturen $T$, definierad enligt
#
# $$T \equiv \left( \frac{\partial E}{\partial S} \right)_{V,N}$$
#
# kallas för *konjungerad* variabel till entropin $S$.
#
# På samma sätt är trycket $P$
#
# $$ P \equiv - \left( \frac{\partial E}{\partial V} \right)_{S,N}$$
#
# konjungerad till volymen $V$ och den kemiska potentialen $\mu$
#
# $$ \mu \equiv \left( \frac{\partial E}{\partial N} \right)_{S,V}$$
#
# konjungerad till partikelantalet $N$.
#
# ***

# %% [markdown]
# # Fundamentala Termodynamiska Relationen
#
# Entropi $S = S(E,V,N)$ lös för $E$ ger
#
# $$ E = E(S,V,N) $$
#
# För förändringar mellan jämviktstillstånd
#
# $$
# dE =
# \left( \frac{\partial E}{\partial S} \right)_{V,N}
# dS
# +
# \left( \frac{\partial E}{\partial V} \right)_{S,N}
# dV
# +
# \left( \frac{\partial E}{\partial N} \right)_{S,V}
# dN
# $$
#
# Insättning av konjungerade variabler ger
#
# $$dE = T dS - P dV + \mu dV \quad\quad \text{(FTR)}$$
#
# ***

# %% [markdown]
# # Termodynamiska potentialer
#
# Intern energi $E$
#
# $$ E = E(S,V,N) $$
#
# Helmholtz fria energi $F$
#
# $$ F = F(T,V,N) $$
#
# Entalpi $H$
#
# $$ H = H(S,P,N) $$
#
# Gibbs fria energi $G$
#
# $$ G = G(T,P,N) $$
#
# Val av potential beror på system.
#
# $F$, $H$ och $G$ kan härledas från $E$ med hjälp av Legendre transform.
#
# ## Exempel: Helmholtz fria energi $F$
#
# $$ F = E - TS $$
#
# $$ dF = dE - TdS - SdT = \left[ \begin{array}{c} \text{Ins.} \\ \text{(FDR)} \end{array} \right] \\
# = TdS - PdV + \mu dV - TdS - SdT \\
# = - SdT - PdV + \mu dN$$
#
# $$ dF = - SdT - PdV + \mu dN \quad \Rightarrow \quad F = F(T, V, N) \quad \blacksquare$$
#
# På samma sätt
#
# $$ H = E + PV \quad \Rightarrow \quad H = H(S,P,N) $$
#
# $$ G = E - TS + PV \quad \Rightarrow \quad G = G(T,P,N) $$
#
# ***

# %% [markdown]
# # Sammanfattning
#
# - Termodynamikens första huvudsats: $$dE = \cancel{d}Q + \cancel{d}W$$
#
# - Termodynamikens andra huvudsats:
#
# $$dS \ge 0 \quad \quad \text{(isolerat system)}$$
#
# - Temperatur $T$
#
# $$T \equiv \left( \frac{\partial E}{\partial S} \right)_{V,N}$$
#
# - Fundamentala termodynamiska relationen
#
# $$dE = T dS - P dV + \mu dV$$
#
# - Termodynamiska potentialer<br><br>
#
#   - Intern energi $$E = E(S,V,N)$$
#
#   - Helmholtz fria energi $$F = F(T,V,N) = E - TS$$
#
#   - Entalpi $$H = H(S,P,N) = E + PV$$
#
#   - Gibbs fria energi $$G = G(T,P,N) = E - TS + PV$$
